# %% [markdown]
# # Análise de desempenho das estratégias de ordenação
#
# ## Objetivo
# Este documento gera os gráficos necessários na análise de desempenho da etapa 1 de nosso roteiro de análise.
#
# ## Descrição
# 1. Modelo de dados deve seguir seguinte padrão do arquivo `/data/experiment1.csv`.
# 2. Configuração das estratégias válidas para a análise.
# 3. Execução da análise e geração dos gráficos.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from performance_analysis import run_performance_analysis

# csv_file = 'data/experiment1.csv'
# mapping = {
#     'a9': ('stRND', 'white'),
#     'b9': ('stCTR', 'darkorange'),
#     'c9': ('stCTX', 'gold'),
#     'd9': ('stBTU', 'darkgreen'),
#     'e9': ('stBID', 'darkred'),
# }
# run_performance_analysis(csv_file, mapping, alpha=0.333, beta=0.333, gamma=0.334, delta=0)

# csv_file = 'data/experiment2.csv'
# mapping = {
#     'a9':          ('stRND' , 'white'),
#     'b9':          ('stCTR' , 'darkorange'),
#     'e9':          ('stBID' , 'darkred'),
#     'f9':          ('stTRAD', 'cyan'),
#     'g9':          ('stUSER', 'darkblue'),
#     'auctionexpr': ('stMKT' , 'purple'),
# }
# run_performance_analysis(csv_file, mapping, alpha=0.333, beta=0.333, gamma=0.334, delta=0)

csv_file = 'data/experiment3.csv'
mapping = {
    'a5':          ('stRND' , 'white'),
    'b5':          ('stBID' , 'darkred'),
    'c5':          ('stCTR' , 'darkorange'),
    'd5':          ('stCTX' , 'gold'),
    'e5':          ('stBTU' , 'darkgreen'),
    'f5':          ('stLCTR', 'grey'),
    'g5':          ('stTRAD', 'cyan'),
    'h5':          ('stUSER', 'darkblue'),
    'auctionexpr': ('stMKT' , 'purple'),
}

run_performance_analysis(csv_file, mapping, alpha=0.333, beta=0.333, gamma=0.334, delta=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
