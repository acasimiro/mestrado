# %% [markdown]
# # Análise de PCA das variáveis de ordenação
#
# ## Objetivo
# Este documento gera os gráficos necessários na análise de PCA da etapa 2 de nosso roteiro de análise.
#
# ## Descrição
# 1. Modelo de dados deve seguir padrão do arquivo `./data/variables-public.csv`.
# 2. Configuração das variáveis consideradas e das componentes principais a serem exibidas.
# 3. Execução da análise e geração dos gráficos.

# %%
source('pca_analysis.R')
csv_file = 'data/variables-public.csv'
variables = c('BID', 'CTR', 'CTX', 'BTU')

run_pca_analysis(csv_file, variables, components=c(1, 2))
run_pca_analysis(csv_file, variables, components=c(3, 4))
# Out:
# Standard deviations:
# [1] 1.0552061 1.0266203 0.9906911 0.9225627
#
# Rotation:
#             PC1        PC2        PC3       PC4
# BID  0.73197884  0.1163807 -0.2067550 0.6386822
# CTR -0.50524691 -0.2438169 -0.7320495 0.3865002
# CTX -0.09280825 -0.7378238  0.5270100 0.4114160
# BTU -0.44757029  0.6185668  0.3789675 0.5229145
# Importance of components:
#                           PC1    PC2    PC3    PC4
# Standard deviation     1.0552 1.0266 0.9907 0.9226
# Proportion of Variance 0.2784 0.2635 0.2454 0.2128
# Cumulative Proportion  0.2784 0.5419 0.7872 1.0000
# pdf
#   2
# Standard deviations:
# [1] 1.0552061 1.0266203 0.9906911 0.9225627
#
# Rotation:
#             PC1        PC2        PC3       PC4
# BID  0.73197884  0.1163807 -0.2067550 0.6386822
# CTR -0.50524691 -0.2438169 -0.7320495 0.3865002
# CTX -0.09280825 -0.7378238  0.5270100 0.4114160
# BTU -0.44757029  0.6185668  0.3789675 0.5229145
# Importance of components:
#                           PC1    PC2    PC3    PC4
# ...
